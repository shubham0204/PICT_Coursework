# %% [markdown]
# 1. Switch to the 'T4 GPU' runner in Google Colab, by going to 'Runtime > Change runtime type'.
# 2. Upload the CUDA code (`.cu` extension file) in Google Colab.
# 3. Use `nvidia-smi` to check GPU device details.
# 4. Use `nvcc`, the Nvidia CUDA compiler, to compile the code and produce an executable.

# %%
# !nvidia-smi
# !nvcc -arch=sm_75 matmul.cu
# !./a.out
