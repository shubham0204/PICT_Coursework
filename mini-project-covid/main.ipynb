# %% [markdown]
# # DSBDL Mini Project
# ```
# Group:
# 31352: Advait Naik
# 31353: Kaustubh Netke
# 31354: Shubham Panchal
# ```
#
# ### Problem Statement
#
# Use the following covid_vaccine_statewise.csv dataset and perform following analytics on the
# given dataset
# https://www.kaggle.com/sudalairajkumar/covid19-inindia?select=covid_vaccine_statewise.csv
#
# a. Describe the dataset
#
# b. Number of persons state wise vaccinated for first dose in India
#
# c. Number of persons state wise vaccinated for second dose in India
#
# d. Number of Males vaccinated
#
# d. Number of females vaccinated

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ### About the dataset

# %%
ds = pd.read_csv( "covid_vaccine_statewise.csv" )

# %%
ds.head()
# Out:
#    Updated On  State  Total Doses Administered  Sessions   Sites   \
# 0  16/01/2021  India                   48276.0    3455.0   2957.0
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
# 2  18/01/2021  India                   99449.0   13611.0   6583.0
# 3  19/01/2021  India                  195525.0   17855.0   7951.0
# 4  20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# ...

# %% [markdown]
# #### Data-types of columns

# %%
ds.dtypes
# Out:
# Updated On                              object
# State                                   object
# Total Doses Administered               float64
# Sessions                               float64
#  Sites                                 float64
# First Dose Administered                float64
# Second Dose Administered               float64
# Male (Doses Administered)              float64
# Female (Doses Administered)            float64
# Transgender (Doses Administered)       float64
#  Covaxin (Doses Administered)          float64
# CoviShield (Doses Administered)        float64
# Sputnik V (Doses Administered)         float64
# AEFI                                   float64
# 18-44 Years (Doses Administered)       float64
# 45-60 Years (Doses Administered)       float64
# 60+ Years (Doses Administered)         float64
# 18-44 Years(Individuals Vaccinated)    float64
# 45-60 Years(Individuals Vaccinated)    float64
# 60+ Years(Individuals Vaccinated)      float64
# ...

# %% [markdown]
# #### Columns in the dataset

# %%
ds.columns
# Out:
# Index(['Updated On', 'State', 'Total Doses Administered', 'Sessions',
#        ' Sites ', 'First Dose Administered', 'Second Dose Administered',
#        'Male (Doses Administered)', 'Female (Doses Administered)',
#        'Transgender (Doses Administered)', ' Covaxin (Doses Administered)',
#        'CoviShield (Doses Administered)', 'Sputnik V (Doses Administered)',
#        'AEFI', '18-44 Years (Doses Administered)',
#        '45-60 Years (Doses Administered)', '60+ Years (Doses Administered)',
#        '18-44 Years(Individuals Vaccinated)',
#        '45-60 Years(Individuals Vaccinated)',
#        '60+ Years(Individuals Vaccinated)', 'Male(Individuals Vaccinated)',
#        'Female(Individuals Vaccinated)', 'Transgender(Individuals Vaccinated)',
#        'Total Individuals Vaccinated'],
#       dtype='object')

# %% [markdown]
# #### Visualizations for no. of doses, sites, sessions

# %%
ax = sns.lineplot( data=ds, x="Updated On", y="Total Doses Administered" )
ax.set(xticklabels=[])
ax.tick_params(bottom=False)
plt.show()

# %%
ax = sns.lineplot( data=ds, x="Updated On", y="Sessions" )
ax.set(xticklabels=[])
ax.tick_params(bottom=False)
plt.show()

# %%
ax = sns.lineplot( data=ds, x="Updated On", y=" Sites " )
ax.set(xticklabels=[])
ax.tick_params(bottom=False)
plt.show()

# %%
ax = sns.lineplot( data=ds[[ "Updated On", "First Dose Administered","Second Dose Administered"]]  )
ax.set(xticklabels=[])
ax.tick_params(bottom=False)
plt.show()

# %% [markdown]
# ### First Dose Administered - aggregated state wise

# %%
first_dose_ds = ds.loc[ (ds[ "First Dose Administered" ] > 0) & (ds["State"] != "India") ]
first_dose_ds = first_dose_ds[ [ "State" , "First Dose Administered" ]  ]
first_dose_ds = first_dose_ds.groupby( "State" ).agg( 'sum' )
first_dose_ds.head()
# Out:
#                              First Dose Administered
# State
# Andaman and Nicobar Islands             1.642585e+07
# Andhra Pradesh                          1.232861e+09
# Arunachal Pradesh                       4.900498e+07
# Assam                                   5.856002e+08
# Bihar                                   1.470503e+09

# %%
ax = sns.barplot( data=first_dose_ds, x="State", y="First Dose Administered" )
ax.tick_params(axis='x', rotation=90)
ax.tick_params(bottom=False)
plt.show()

# %% [markdown]
# ### Second Dose Administered - aggregated state wise

# %%
second_dose_ds = ds.loc[ (ds[ "Second Dose Administered" ] > 0) & (ds["State"] != "India") ]
second_dose_ds = second_dose_ds[ [ "State" , "Second Dose Administered" ]  ]
second_dose_ds = second_dose_ds.groupby( "State" ).agg( 'sum' )
second_dose_ds.head()
# Out:
#                              Second Dose Administered
# State
# Andaman and Nicobar Islands                 4118554.0
# Andhra Pradesh                            358817595.0
# Arunachal Pradesh                          11932317.0
# Assam                                     130788792.0
# Bihar                                     270790571.0

# %%
ax = sns.barplot( data=second_dose_ds, x="State", y="Second Dose Administered" )
ax.tick_params(axis='x', rotation=90)
ax.tick_params(bottom=False)
plt.show()

# %% [markdown]
# ### Number of males vaccinated - aggregated state wise

# %%
sub = ds.loc[ (ds[ "Male (Doses Administered)" ] > 0) & (ds["State"] != "India") ]
sub = sub[ [ "State" , "Male (Doses Administered)" ]  ]
sub = sub.groupby( "State" ).agg( 'sum' )
sub.head()
# Out:
#                              Male (Doses Administered)
# State
# Andaman and Nicobar Islands                 10453750.0
# Andhra Pradesh                             677669372.0
# Arunachal Pradesh                           30615798.0
# Assam                                      355793883.0
# Bihar                                      869394635.0

# %%
ax = sns.barplot( data=sub, x="State", y="Male (Doses Administered)" )
ax.tick_params(axis='x', rotation=90)
ax.tick_params(bottom=False)
plt.show()

# %% [markdown]
# ### Number of females vaccinated - aggregated state wise

# %%
sub = ds.loc[ (ds[ "Female (Doses Administered)" ] > 0) & (ds["State"] != "India") ]
sub = sub[ [ "State" , "Female (Doses Administered)" ]  ]
sub = sub.groupby( "State" ).agg( 'sum' )
sub.head()
# Out:
#                              Female (Doses Administered)
# State
# Andaman and Nicobar Islands                    8964974.0
# Andhra Pradesh                               755053860.0
# Arunachal Pradesh                             24635938.0
# Assam                                        303511268.0
# Bihar                                        747214483.0

# %%
ax = sns.barplot( data=sub, x="State", y="Female (Doses Administered)" )
ax.tick_params(axis='x', rotation=90)
ax.tick_params(bottom=False)
plt.show()
